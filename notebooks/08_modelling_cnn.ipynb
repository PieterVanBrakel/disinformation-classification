# %%
# Standard library
from pathlib import Path

# Third-party libraries
import joblib
import pandas as pd
import numpy as np

from tensorflow.keras.layers import Embedding, MaxPooling1D, Flatten
import tensorflow as tf
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Variables

# Data
try:
    PROJECT_ROOT = Path(__file__).resolve().parents[1]
except NameError:
    # fallback for notebooks or interactive environments
    PROJECT_ROOT = Path.cwd().parent

DATA_INTERIM_DIR: Path = PROJECT_ROOT / "data" / "interim"
MODEL_EXPERIMENT_DIR: Path = PROJECT_ROOT / "models" / "experiment"

param_grid = {
    "batch_size": [32, 64],
    "epochs": [5, 10],
    "model__filters": [64, 128],
    "model__kernel_size": [3, 5],
    "model__dropout_rate": [0.3, 0.5]
}

# %%
# Load preprocessed tokenized data
X_train = joblib.load(DATA_INTERIM_DIR / "X_train.pkl")  # tokenized train texts
y_train = joblib.load(DATA_INTERIM_DIR / "y_train.pkl")  # train labels

X_test = joblib.load(DATA_INTERIM_DIR / "X_test.pkl")    # tokenized test texts
y_test = joblib.load(DATA_INTERIM_DIR / "y_test.pkl")    # test labels

print(f"Train size: {len(X_train)}")  
print(f"Test size:  {len(X_test)}")
# Out:
# Train size: 57229
# Test size:  14308

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

MAX_FEATURES = 20000

# 1: Convert token lists back to strings (Tokenizer expects text)
X_train_text = X_train.apply(lambda tokens: " ".join(tokens))
X_test_text  = X_test.apply(lambda tokens: " ".join(tokens))

# 2: Build a Tokenizer (or use one saved earlier)
tokenizer = Tokenizer(num_words=MAX_FEATURES, oov_token="<OOV>")

# 3: Fit the tokenizer only on training data to avoid data leakage.
tokenizer.fit_on_texts(X_train_text)

# 4: transform the training and test data from texts to numbers
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq  = tokenizer.texts_to_sequences(X_test)

from tensorflow.keras.preprocessing.sequence import pad_sequences

MAX_LEN = 200

# 5: Pad sequences to transform the shape for the X_values for the CNN

# 5.1 For the training data
X_train_pad = pad_sequences(
    X_train_seq,
    maxlen=MAX_LEN,
    padding="post",
    truncating="post"
)

# For the test data
X_test_pad = pad_sequences(
    X_test_seq,
    maxlen=MAX_LEN,
    padding="post",
    truncating="post"
)

# 6: Transform the y_values for the CNN

y_train = y_train.values if hasattr(y_train, "values") else y_train
y_test = y_test.values if hasattr(y_test, "values") else y_test


# 7: Create a model-building function for GridSearch

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout

from tensorflow.keras.layers import Input

def create_cnn_model(
    filters=128,
    kernel_size=5,
    dense_units=64,
    dropout_rate=0.5,
    optimizer="adam"
):
    model = Sequential(name="cnn_text_classifier")

    # Explicit input layer (THIS FIXES THE ERROR)
    model.add(Input(shape=(MAX_LEN,)))

    model.add(Embedding(input_dim=MAX_FEATURES, output_dim=128))
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation="relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units, activation="relu"))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation="sigmoid"))

    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# 8: Wrap with Kerasclassfier

model = KerasClassifier(
    model=create_cnn_model,
    verbose=0
)

# 9 Run the model with gridsearch

grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=3,
    scoring="accuracy",
    verbose=2,
    n_jobs=-1
)

grid.fit(X_train_pad, y_train)

# 10: Evaluate the best model

print("Best score:", grid.best_score_)
print("Best params:", grid.best_params_)

best_model = grid.best_estimator_

y_pred = best_model.predict(X_test_pad)

from sklearn.metrics import accuracy_score

print("Test accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=32.8min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=32.8min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=33.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=126.0min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=126.0min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=126.0min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=157.8min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=157.8min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=248.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=370.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=370.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=398.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=398.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=398.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=492.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=445.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=487.9min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=495.7min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=464.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=492.9min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=431.5min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=488.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=488.1min
# [CV] END batch_size=32, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=512.1min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=512.0min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=512.4min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=621.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=933.2min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=890.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=887.0min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=944.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=916.0min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=624.3min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=624.3min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=888.3min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=455.8min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=717.7min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=718.1min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=72.1min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=633.9min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=72.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=68.4min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time= 3.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=13.2min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time= 3.6min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time= 3.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=13.6min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=13.0min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time= 5.5min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time= 5.4min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time= 5.4min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=17.7min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time= 3.8min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time= 3.8min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time= 3.9min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=19.0min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time= 7.7min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time= 7.7min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time= 7.7min
# [CV] END batch_size=32, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=18.8min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time= 4.9min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time= 5.6min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time= 5.4min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time= 5.5min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=10.7min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=11.0min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=10.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=10.9min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=3; total time=11.5min
# [CV] END batch_size=64, epochs=5, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=11.8min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=15.1min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=14.9min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=64, model__kernel_size=5; total time=15.2min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=16.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=16.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=3; total time=16.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time=10.0min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time= 9.6min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=3; total time= 9.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=21.9min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=14.0min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=14.0min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=64, model__kernel_size=5; total time=14.0min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=21.8min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.3, model__filters=128, model__kernel_size=5; total time=21.4min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=17.4min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=17.7min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=3; total time=17.5min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=33.4min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=33.3min
# [CV] END batch_size=64, epochs=10, model__dropout_rate=0.5, model__filters=128, model__kernel_size=5; total time=33.5min
# Best score: 0.9719897553934148
# Best params: {'batch_size': 32, 'epochs': 5, 'model__dropout_rate': 0.3, 'model__filters': 128, 'model__kernel_size': 3}
# Test accuracy: 0.974769359798714

# %% [markdown]
# Sources:
#
# - https://www.kaggle.com/code/yacharki/10-classses-yahoo-answers-41-cnn
#
# Stappen:
# 1. Download libraries
# 2. Bouw preprocessing functie
# 3. Laad de dataset
# 4. Laat NA waardes vallen
# 5. Split de X en y waardes
# 6. Preprocess de X waardes
# 7. Tokenize de X waardes

# %%
import pandas as pd # For loading the dataframe
import matplotlib.pyplot as plt # For plotting the graphs
import pickle # For saving and loading
import numpy as np # Used for processing
import seaborn as sns # For the confusion matrix

import nltk # Used for preprocessing
import string # Used for preprocessing
from nltk.tokenize import word_tokenize # Used for preprocessing
from nltk.corpus import stopwords # Used for preprocessing
from nltk.stem   import WordNetLemmatizer # Used for preprocessing

from tensorflow.keras.preprocessing.text import Tokenizer # For the word embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences # For the word embedding
from tensorflow.keras.models import model_from_json

from sklearn.model_selection import train_test_split # For splitting the data

from tensorflow.keras import Sequential # Used for building the CNN
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Activation, Dense, Dropout # Used for building the CNN

from sklearn.metrics import classification_report # Used for model evaluation
from sklearn.metrics import confusion_matrix # Used for model evaluation

# %%
def preprocess_text(text):
    
    def processor(j):
        j = ' '.join([c for c in j if c not in string.punctuation and c not in string.digits])
        tokens = word_tokenize(j, 'english')
        lowered = [x.lower() for x in tokens]
        lemmatiser = WordNetLemmatizer()
        lemmatized = [lemmatiser.lemmatize(word) for word in lowered]
        sw = stopwords.words('english')
        stopped = [word for word in lemmatized if word.lower() not in sw]
        return stopped
    
    end = []
    for i in text[:]:
        i = i.split(" ")
        end.append(processor(i))
        
    return end

# %%
# Loading the dataset
df = pd.read_csv('WELFake_Dataset.csv', index_col = 0)
df = df.dropna()

# %%
# Splitting the data

X = df['text']
y = df['label']

#X = X[:1000]
#y = y[:1000]

# Splitting

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101) # Separating train data
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size = 0.5, random_state = 101) # Separating train data

X_train = X_train.values
X_test = X_test.values
X_val = X_val.values
y_train = y_train.values
y_test = y_test.values
y_val = y_val.values

# %%
X_train = preprocess_text(X_train)
X_test = preprocess_text(X_test)
X_val = preprocess_text(X_val)

# %%
t = Tokenizer(oov_token='<UNK>')
# fit the tokenizer on train documents
t.fit_on_texts(X_train)
t.word_index['<PAD>'] = 0
X_train = t.texts_to_sequences(X_train)
X_test = t.texts_to_sequences(X_test)
X_val = t.texts_to_sequences(X_val)
X_train = pad_sequences(X_train, maxlen=800)
X_test = pad_sequences(X_test, maxlen=800)
X_val = pad_sequences(X_val, maxlen=800)
VOCAB_SIZE = len(t.word_index)
EMBED_SIZE = 800

# %%
t = Tokenizer(oov_token='<UNK>')
# fit the tokenizer on train documents
t.fit_on_texts(X_train)
t.word_index['<PAD>'] = 0

# %%
X_train = t.texts_to_sequences(X_train)
X_test = t.texts_to_sequences(X_test)
X_val = t.texts_to_sequences(X_val)

# %%
X_train = pad_sequences(X_train, maxlen=800)
X_test = pad_sequences(X_test, maxlen=800)
X_val = pad_sequences(X_val, maxlen=800)

# %%
VOCAB_SIZE = len(t.word_index)
EMBED_SIZE = 800

# %%
from tensorflow.keras.layers import Embedding, MaxPooling1D, Flatten
import tensorflow as tf
model = Sequential()
# The Embedding layer
model.add(Embedding(VOCAB_SIZE, EMBED_SIZE, input_length=800))
# The first one dimensional convolutional layer (32,4,same,relu)
model.add(Conv1D(filters=32, kernel_size=4, padding='same', activation='relu'))
model.add(Conv1D(filters=32, kernel_size=4, padding='same', activation='relu'))
# The first Max pooling layer (2)
model.add(MaxPooling1D(pool_size=2))
# The first Dropout layer (10%)
model.add(Dropout(rate=0.10))
# The second one dimensional convolutional layer (32,4,same,relu)
model.add(Conv1D(filters=64, kernel_size=4, padding='same', activation='relu'))
model.add(Conv1D(filters=64, kernel_size=4, padding='same', activation='relu'))
# The second Max pooling layer (2)
model.add(MaxPooling1D(pool_size=2))
# The second Dropout layer (10%)
model.add(Dropout(rate=0.10))
# The third one dimensional convolutional layer (32,4,same,relu)
model.add(Conv1D(filters=64, kernel_size=4, padding='same', activation='relu'))
model.add(Conv1D(filters=64, kernel_size=4, padding='same', activation='relu'))
# The third Max pooling layer (2)
model.add(MaxPooling1D(pool_size=2))
# The third Dropout layer (10%)
model.add(Dropout(rate=0.10))
# The Flattening layer
model.add(Flatten())
# The First Dense Layer (256,relu)
model.add(Dense(256, activation='relu'))
# The Second Dense Layer or Prediction layer (1,sigmoid)
model.add(Dense(10, activation='softmax'))
# Compiling the Model using the Binary_Crossontropy as a loss function and accuracy as a meseaure and Adam as an Optimizer
model.compile(loss='SparseCategoricalCrossentropy', optimizer=tf.keras.optimizers.Adam(1e-4), metrics=['accuracy'])
# Displaying the Model Schema
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 800, 800)          265860000
#
#  conv1d_6 (Conv1D)           (None, 800, 32)           102432
#
#  conv1d_7 (Conv1D)           (None, 800, 32)           4128
#
#  max_pooling1d_3 (MaxPooling  (None, 400, 32)          0
#  1D)
#
#  dropout_3 (Dropout)         (None, 400, 32)           0
#
#  conv1d_8 (Conv1D)           (None, 400, 64)           8256
#
#  conv1d_9 (Conv1D)           (None, 400, 64)           16448
#
#  max_pooling1d_4 (MaxPooling  (None, 200, 64)          0
#  1D)
#
#  dropout_4 (Dropout)         (None, 200, 64)           0
#
#  conv1d_10 (Conv1D)          (None, 200, 64)           16448
#
#  conv1d_11 (Conv1D)          (None, 200, 64)           16448
#
#  max_pooling1d_5 (MaxPooling  (None, 100, 64)          0
#  1D)
#
#  dropout_5 (Dropout)         (None, 100, 64)           0
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_2 (Dense)             (None, 256)               1638656
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 267,665,386
# Trainable params: 267,665,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
with tf.device('/GPU:0'):
    history1 = model.fit(X_train, y_train, validation_data=(X_val,y_val),epochs=20, batch_size=64, verbose=1)
# Out:
# Epoch 1/20
# 203/895 [=====>........................] - ETA: 10:22:26 - loss: 0.6676 - accuracy: 0.6838
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-90a2cc3cc37f> in <module>
#       1 with tf.device('/GPU:0'):
# ----> 2     history1 = model.fit(X_train, y_train, validation_data=(X_val,y_val),epochs=20, batch_size=64, verbose=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
max_features = max([len(s.split()) for s in X])

# %%
# Word embedding

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_prep)
encoded_docs = tokenizer.texts_to_sequences(X_prep)
X_train = pad_sequences(encoded_docs, maxlen=max_features, padding='post')

#tokenizer = Tokenizer() # Tokenizing the text into numbers
#tokenizer.fit_on_texts(texts = X_pre) # Building the vocabulary
#X = tokenizer.texts_to_sequences(texts = X_pre) # Tokenized words as X data from the train dataset
#X_train = pad_sequences(sequences = X, maxlen = max_features, padding = 'post')

# %%
encoded_docs = tokenizer.texts_to_sequences(X_test_prep)
X_test = pad_sequences(encoded_docs, maxlen=max_features, padding='post')

# %%
# Padding and transforming to array

#X = pad_sequences(sequences = X, maxlen = max_features, padding = 'pre')
# X = An array shaped 20, 512 with the indexed words in there.
y_train = y_train.values
y_test = y_test.values
# Y is transformed from an index class to a array

# %%
# Hyperparameters

batch_size = 64
embedding_dims = 1 #Length of the token vectors
filters = 250 #number of filters in your Convnet
kernel_size = 3 # a window size of 3 tokens
hidden_dims = 250 #number of neurons at the normal feedforward NN
epochs = 8
maxlen = max_features

# %%
from tensorflow.keras.layers import Flatten

cnn_model = Sequential(name = "CNN_model")
cnn_model.add(Conv1D(filters, kernel_size, padding = 'valid', 
                 activation = 'relu', strides = 1, input_shape = (maxlen,embedding_dims), name = "1st_layer"))
cnn_model.add(GlobalMaxPooling1D(name = "2nd_layer"))
cnn_model.add(Dense(hidden_dims, name = "3rd_layer"))
#cnn_model.add(Dropout(0.2, name = "4th_layer"))
cnn_model.add(Activation('relu', name = "5th_layer"))
cnn_model.add(Dense(1, name = "6th_layer"))
cnn_model.add(Activation('sigmoid', name = "7th_layer"))
# Compiling the model
cnn_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
history = cnn_model.fit(X_train, y_train, 
          batch_size = batch_size, epochs = epochs, validation_data = (X_test,y_test))
# Out:
# Epoch 1/8
# 13/13 [==============================] - 77s 6s/step - loss: 350.1200 - accuracy: 0.5163 - val_loss: 73.1529 - val_accuracy: 0.4650
# Epoch 2/8
# 13/13 [==============================] - 73s 6s/step - loss: 69.8817 - accuracy: 0.6413 - val_loss: 63.4894 - val_accuracy: 0.4750
# Epoch 3/8
# 13/13 [==============================] - 73s 6s/step - loss: 174.4448 - accuracy: 0.5537 - val_loss: 76.6887 - val_accuracy: 0.5200
# Epoch 4/8
# 13/13 [==============================] - 78s 6s/step - loss: 153.1010 - accuracy: 0.5375 - val_loss: 164.0726 - val_accuracy: 0.5250
# Epoch 5/8
# 13/13 [==============================] - 81s 6s/step - loss: 78.9560 - accuracy: 0.6112 - val_loss: 55.0671 - val_accuracy: 0.5100
# Epoch 6/8
# 13/13 [==============================] - 88s 7s/step - loss: 73.5890 - accuracy: 0.5863 - val_loss: 89.5587 - val_accuracy: 0.4300
# Epoch 7/8
# 13/13 [==============================] - 86s 7s/step - loss: 81.8756 - accuracy: 0.5850 - val_loss: 96.5772 - val_accuracy: 0.5200
# Epoch 8/8
# 13/13 [==============================] - 81s 6s/step - loss: 51.3369 - accuracy: 0.6112 - val_loss: 43.3742 - val_accuracy: 0.4950
